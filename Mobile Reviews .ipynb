# %%
import numpy as np
import pandas as pd
import plotly.express as px
import streamlit as st

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Mobile Reviews Sentiment.csv')
df
# Out:
#        review_id          customer_name  age     brand            model  \
# 0              1          Aryan Maharaj   45    Realme    Realme 12 Pro
# 1              2      Davi Miguel Sousa   18    Realme    Realme 12 Pro
# 2              3            Pahal Balay   27    Google          Pixel 6
# 3              4           David Guzman   19    Xiaomi    Redmi Note 13
# 4              5              Yago Leão   38  Motorola          Edge 50
# ...          ...                    ...  ...       ...              ...
# 49995      49996          Rebecca Pratt   18    Realme    Realme 12 Pro
# 49996      49997  Dr. Tiffany Patterson   28   Samsung   Galaxy Note 20
# 49997      49998        Alexandra Singh   21     Apple        iPhone SE
# 49998      49999          Robert Morris   31    Realme  Realme Narzo 70
# 49999      50000       Regina Dennis MD   44  Motorola     Moto G Power
#
#        price_usd price_local currency  exchange_rate_to_usd  rating  \
# ...

# %% [markdown]
# ### 📊 Columns Description

# %% [markdown]
# # Data Exploration

# %%
# Check data types 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   review_id             50000 non-null  int64
#  1   customer_name         50000 non-null  object
#  2   age                   50000 non-null  int64
#  3   brand                 50000 non-null  object
#  4   model                 50000 non-null  object
#  5   price_usd             50000 non-null  float64
#  6   price_local           50000 non-null  object
#  7   currency              50000 non-null  object
#  8   exchange_rate_to_usd  50000 non-null  float64
#  9   rating                50000 non-null  int64
#  10  review_text           50000 non-null  object
#  11  sentiment             50000 non-null  object
#  12  country               50000 non-null  object
#  13  language              50000 non-null  object
#  14  review_date           50000 non-null  object
# ...

# %% [markdown]
# * Check summary statistics for `Numerical` columns

# %%
df.describe(include='number').round(2)
# Out:
#        review_id       age  price_usd  exchange_rate_to_usd    rating  \
# count   50000.00  50000.00   50000.00              50000.00  50000.00
# mean    25000.50     30.08     689.69                 12.06      3.12
# std     14433.90      8.93     310.31                 26.55      1.25
# min         1.00     18.00     180.02                  0.78      1.00
# 25%     12500.75     23.00     450.79                  1.00      2.00
# 50%     25000.50     29.00     637.04                  1.53      3.00
# 75%     37500.25     36.00     900.98                  5.70      4.00
# max     50000.00     65.00    1499.89                 83.00      5.00
#
#        battery_life_rating  camera_rating  performance_rating  design_rating  \
# count             50000.00       50000.00            50000.00       50000.00
# mean                  2.72           2.72                2.72           2.71
# std                   1.35           1.35                1.35           1.34
# ...

# %% [markdown]
# * Check summary statistics for `Categorical` columns

# %%
df.describe(include='object')
# Out:
#         customer_name   brand            model price_local currency  \
# count           50000   50000            50000       50000    50000
# unique          45911       7               22       48418        8
# top     Michael Smith  Xiaomi  Realme Narzo 70    R$2272.3      USD
# freq               16    7241             3597           4     6435
#
#                                               review_text sentiment country  \
# count                                               50000     50000   50000
# unique                                                110         3       8
# top     Battery easily lasts a day with heavy use. No ...  Positive     USA
# freq                                                  724     27540    6435
#
#        language review_date source
# count     50000       50000  50000
# unique        4        1096      5
# top     English  2023-04-05   eBay
# freq      31295          67  10052

# %% [markdown]
# - Check Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - Check Missing Values

# %%
df.isna().sum()
# Out:
# review_id               0
# customer_name           0
# age                     0
# brand                   0
# model                   0
# price_usd               0
# price_local             0
# currency                0
# exchange_rate_to_usd    0
# rating                  0
# review_text             0
# sentiment               0
# country                 0
# language                0
# review_date             0
# verified_purchase       0
# battery_life_rating     0
# camera_rating           0
# performance_rating      0
# design_rating           0
# display_rating          0
# review_length           0
# word_count              0
# helpful_votes           0
# source                  0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
# make all column names lowercase 
df.columns = df.columns.str.lower().str.strip()
df.columns
# Out:
# Index(['review_id', 'customer_name', 'age', 'brand', 'model', 'price_usd',
#        'price_local', 'currency', 'exchange_rate_to_usd', 'rating',
#        'review_text', 'sentiment', 'country', 'language', 'review_date',
#        'verified_purchase', 'battery_life_rating', 'camera_rating',
#        'performance_rating', 'design_rating', 'display_rating',
#        'review_length', 'word_count', 'helpful_votes', 'source'],
#       dtype='object')

# %%
# in depth check for categorical columns
cat_cols=df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['customer_name', 'brand', 'model', 'price_local', 'currency',
#        'review_text', 'sentiment', 'country', 'language', 'review_date',
#        'source'],
#       dtype='object')

# %%
for col in cat_cols:
    print(col)
    print(df[col].nunique())
    print(df[col].unique())
    print(df[col].value_counts())
    print('#' * 50)
# Out:
# customer_name
# 45911
# ['Aryan Maharaj' 'Davi Miguel Sousa' 'Pahal Balay' ... 'Alexandra Singh'
#  'Robert Morris' 'Regina Dennis MD']
# customer_name
# Michael Smith           16
# Christopher Johnson     15
# Michael Williams        14
# David Smith             14
# John Smith              10
#                         ..
# Holly Reed               1
# Srta. Isadora Novais     1
# Brian Thorpe             1
# Lucy Hodgson             1
# Cheryl Campos            1
# Name: count, Length: 45911, dtype: int64
# ##################################################
# brand
# 7
# ['Realme' 'Google' 'Xiaomi' 'Motorola' 'Apple' 'OnePlus' 'Samsung']
# brand
# Xiaomi      7241
# Google      7234
# Apple       7144
# OnePlus     7136
# Realme      7132
# Motorola    7061
# Samsung     7052
# Name: count, dtype: int64
# ##################################################
# model
# 22
# ['Realme 12 Pro' 'Pixel 6' 'Redmi Note 13' 'Edge 50' 'iPhone 14'
# ...

# %%
# in depth check for numerical columns
num_cols=df.select_dtypes(include='number').columns
num_cols
# Out:
# Index(['review_id', 'age', 'price_usd', 'exchange_rate_to_usd', 'rating',
#        'battery_life_rating', 'camera_rating', 'performance_rating',
#        'design_rating', 'display_rating', 'review_length', 'word_count',
#        'helpful_votes'],
#       dtype='object')

# %%
px.defaults.template = 'plotly_white'

# %%
# visualize the distribution of numerical columns using histogram and box plot
for col in num_cols:
   px.histogram(data_frame=df, x=col, title=col,color_discrete_sequence=['blue']).show()
   px.box(data_frame=df, x=col, title=col,color_discrete_sequence=['red']).show()

# %%
# relationship between features and target columns
corr_df = df.corr(numeric_only=True).round(2)
px.imshow( corr_df,text_auto=True,color_continuous_scale='RdBu',width=00,height=700).show()

# %%
# drop unnecessary columns and after checking i removed the columns that have rating because they are highly correlated with the target column and they are not useful for the model
df.drop(['review_id','customer_name','currency','review_date','price_local','exchange_rate_to_usd','rating','battery_life_rating','camera_rating','performance_rating','design_rating','display_rating','review_text','helpful_votes'], inplace=True, axis=1)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#        age     brand            model  price_usd sentiment    country  \
# 0       45    Realme    Realme 12 Pro     337.31  Negative      India
# 1       18    Realme    Realme 12 Pro     307.78  Positive     Brazil
# 2       27    Google          Pixel 6     864.53  Positive      India
# 3       19    Xiaomi    Redmi Note 13     660.94  Positive        UAE
# 4       38  Motorola          Edge 50     792.13   Neutral     Brazil
# ...    ...       ...              ...        ...       ...        ...
# 49995   18    Realme    Realme 12 Pro     526.10  Positive  Australia
# 49996   28   Samsung   Galaxy Note 20     911.85   Neutral  Australia
# 49997   21     Apple        iPhone SE    1155.32  Positive        UAE
# 49998   31    Realme  Realme Narzo 70     459.04  Positive        USA
# 49999   44  Motorola     Moto G Power     380.16  Positive        USA
#
#          language  verified_purchase  review_length  word_count      source
# ...

# %%
df.to_csv('Mobile_Reviews_Cleaned.csv', index=False)

# %% [markdown]
# # Data Analysis

# %%
#What is the overall distribution of customer sentiments?
sentiment_counts = df['sentiment'].value_counts().reset_index()
sentiment_counts.columns = ['Sentiment', 'Count']

px.pie(
    sentiment_counts,
    names='Sentiment',
    values='Count',
    hole=0.5,
    title='Sentiment Distribution'
)

# %%
#What is the distribution of smartphone prices in the dataset?
px.histogram(
    df,
    x='price_usd',
    nbins=40,
    title='Price Distribution'
)

# %%
#Is there a relationship between product price and customer sentiment?
px.box(
    df,
    x='sentiment',
    y='price_usd',
    color='sentiment'
)

# %%
#Which countries contribute the most customer reviews?
px.bar(
    df['country'].value_counts().reset_index(),
    x='country',
    y='count',
    title='Reviews by Country',
    text_auto=True
)

# %%
#Do verified purchasers tend to leave more positive reviews?
px.histogram(
    df,
    x='verified_purchase',
    color='sentiment',
    barmode='group'
)

# %%
# check the distribution of target column 
df['sentiment'].value_counts(normalize=True).round(2) *100
# Out:
# sentiment
# Positive    55.0
# Neutral     25.0
# Negative    20.0
# Name: proportion, dtype: float64

# %% [markdown]
# # Pre-For Machine Learning

# %%
x = df.drop('sentiment',axis=1)
y = df['sentiment']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
numerical_cols = x.select_dtypes(include='number').columns
numerical_pipeline = Pipeline([('scaler', RobustScaler()) ])
numerical_pipeline
# Out:
# Pipeline(steps=[('scaler', RobustScaler())])

# %%
for col in x.select_dtypes(include='object').columns:
    print(col) 
    print(x[col].nunique())
    print('#' * 50)
# Out:
# brand
# 7
# ##################################################
# model
# 22
# ##################################################
# country
# 8
# ##################################################
# language
# 4
# ##################################################
# source
# 5
# ##################################################

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_cols = ['brand', 'country', 'language', 'source']
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore',drop='first')
onehot_pipeline = Pipeline([('onehot', ohe) ])
onehot_pipeline
# Out:
# Pipeline(steps=[('onehot',
#                  OneHotEncoder(drop='first', handle_unknown='ignore',
#                                sparse_output=False))])

# %%
from category_encoders import BinaryEncoder
binary_cols =['model']
be = BinaryEncoder(cols=binary_cols)
binary_pipeline = Pipeline([('binary', be) ])
binary_pipeline
# Out:
# Pipeline(steps=[('binary', BinaryEncoder(cols=['model']))])

# %%
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('Numerical', numerical_pipeline, numerical_cols),
    ('OneHot', onehot_pipeline, onehot_cols),
    ('Binary', binary_pipeline, binary_cols)], remainder='passthrough')
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Numerical',
#                                  Pipeline(steps=[('scaler', RobustScaler())]),
#                                  Index(['age', 'price_usd', 'review_length', 'word_count'], dtype='object')),
#                                 ('OneHot',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['brand', 'country', 'language', 'source']),
#                                 ('Binary',
#                                  Pipeline(steps=[('binary',
#                                                   BinaryEncoder(cols=['model']))]),
#                                  ['model'])])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
#----------------------------------------------------------
models = [
    ('Logistic Regression', LogisticRegression(random_state=42)),
    ('KNN', KNeighborsClassifier(n_neighbors=5)),
    ('Decision Tree', DecisionTreeClassifier(random_state=42)),
    ('Random Forest', RandomForestClassifier(random_state=42)),
    ('CatBoost', CatBoostClassifier(random_state=42)),
  #  ('XGBoost', XGBClassifier(random_state=42)), ----------------> this needs a lable encoder for the target column
    ('LightGBM', LGBMClassifier(random_state=42))
]


for model in models:
    model_pipline = Pipeline(steps=[('Preprocessing',preprocessor),('Model',model[1])])
    
    result = cross_validate(model_pipline, x, y, cv=5, scoring='f1_weighted', return_train_score=True)
    print(model[0])
    print(f"Train F1 Score: {result['train_score'].mean().round(2) * 100:.2f}%")
    print(f"Test F1 Score: {result['test_score'].mean().round(2) * 100:.2f}%")
    print('--------------------------------------------------')
# Out:
# Logistic Regression
# Train F1 Score: 50.00%
# Test F1 Score: 50.00%
# --------------------------------------------------
# KNN
# Train F1 Score: 67.00%
# Test F1 Score: 50.00%
# --------------------------------------------------
# Decision Tree
# Train F1 Score: 100.00%
# Test F1 Score: 86.00%
# --------------------------------------------------
# Random Forest
# Train F1 Score: 100.00%
# Test F1 Score: 75.00%
# --------------------------------------------------
# Learning rate set to 0.095505
# 0:	learn: 1.0410211	total: 119ms	remaining: 1m 58s
# 1:	learn: 0.9905253	total: 127ms	remaining: 1m 3s
# 2:	learn: 0.9490732	total: 133ms	remaining: 44.4s
# 3:	learn: 0.9132319	total: 141ms	remaining: 35.1s
# 4:	learn: 0.8801206	total: 148ms	remaining: 29.5s
# 5:	learn: 0.8482397	total: 156ms	remaining: 25.8s
# 6:	learn: 0.8186018	total: 163ms	remaining: 23.2s
# 7:	learn: 0.7986836	total: 171ms	remaining: 21.2s
# 8:	learn: 0.7817664	total: 178ms	remaining: 19.6s
# ...

# %%
# CatBoost hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostClassifier
para_grid = {
    'Model__iterations': [100, 200, 300, 400, 500],
    'Model__learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
    'Model__depth': [3, 5, 7, 9, 11],
    'Model__l2_leaf_reg': [1, 3, 5]
}

model_pipline = Pipeline(steps=[('Preprocessing',preprocessor),('Model',CatBoostClassifier(random_state=42, verbose=0))])
random_search = RandomizedSearchCV(estimator=model_pipline, param_distributions=para_grid, n_iter=10, cv=5, scoring='f1_weighted', n_jobs=-1, random_state=42)


random_search.fit(x, y)

print("Best Score:", random_search.best_score_)
print("Best Params:", random_search.best_params_)
# Out:
# Best Score: 0.8926152464927501
# Best Params: {'Model__learning_rate': 0.05, 'Model__l2_leaf_reg': 3, 'Model__iterations': 400, 'Model__depth': 5}

# %%
final_pipeline = Pipeline(steps=[('Preprocessing',preprocessor),('Model',CatBoostClassifier(random_state=42, n_estimators=400, max_depth=5, l2_leaf_reg=3, learning_rate=0.05, verbose=0))])
final_pipeline.fit(x, y)
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Numerical',
#                                                   Pipeline(steps=[('scaler',
#                                                                    RobustScaler())]),
#                                                   Index(['age', 'price_usd', 'review_length', 'word_count'], dtype='object')),
#                                                  ('OneHot',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['brand', 'country',
# ...

# %%
import joblib
joblib.dump(final_pipeline, 'MobileReviews_model.pkl')
# Out:
# ['MobileReviews_model.pkl']

# %%
#%%writefile Overview.py
import streamlit as st
import pandas as pd
import plotly.express as px
import os

# 1. Page Basic Configuration
st.set_page_config(
    page_title="Data Overview",
    page_icon="📊",
    layout="wide"
)

# 2. Simple & Fast Data Loading
@st.cache_data
def load_data():
    if os.path.exists("Mobile_Reviews_Cleaned.csv"):
        return pd.read_csv("Mobile_Reviews_Cleaned.csv")
    elif os.path.exists("Mobile Reviews Sentiment.csv"):
        return pd.read_csv("Mobile Reviews Sentiment.csv")
    return None

df = load_data()

# Check if data exists
if df is not None:
    
    # --- SECTION 1: WELCOME HEADER ---
    st.title("📱 Mobile Customer Reviews Analytics")
    st.divider()
    
    # --- SECTION 2: DATASET BRIEF ---
    st.markdown("#### 📝 Dataset Brief")
    st.markdown("""
    This dataset contains consumer reviews and feedback for various mobile phones across multiple e-commerce platforms. 
    It combines **customer demographics** (age, country), **device details** (brand, model, price), and **text properties** (review length, word count) 
    to understand and analyze customer satisfaction and sentiment trends.
    """)
    st.divider()

    # --- SECTION 3: POLISHED KPI CARDS ---
    st.markdown("#### ⚡ Quick Dataset Highlights")
    
    kpi1, kpi2, kpi3, kpi4 = st.columns(4)
    with kpi1:
        st.subheader("📝 Total Dataset Rows")
        st.info(f"**{df.shape[0]:,}** Verified Reviews")
    with kpi2:
        st.subheader("📐 Total Features")
        st.success(f"**{df.shape[1]}** Data Columns")
    with kpi3:
        st.subheader("🏢 Market Brands")
        st.warning(f"**{df['brand'].nunique()}** Smartphone Makers")
    with kpi4:
        st.subheader("💵 Financial Value")
        st.error(f"**${df['price_usd'].mean().round(2)}** Average Price")
        
    st.divider()

    # --- SECTION 4: CLEAN DATA PREVIEW WITH DYNAMIC SLIDER ---
    st.markdown("#### 🔍 Dataset Structure Preview")
    
    # Dynamic slider allowing users to choose how many rows to display
    max_available_rows = min(100, df.shape[0])
    rows_to_show = st.slider(
        label="Select number of rows to display below:", 
        min_value=5, 
        max_value=max_available_rows, 
        value=5, 
        step=5
    )
    
    st.dataframe(
        df.head(rows_to_show), 
        use_container_width=True,
        hide_index=True
    )
    
    st.divider()

    # --- SECTION 5: ELEGANT VISUALIZATION ---
    st.markdown("#### 🎯 Overall Sentiment Share")

    # Group data for the chart
    sentiment_counts = df["sentiment"].value_counts().reset_index()
    sentiment_counts.columns = ["Sentiment Class", "Total Reviews"]

    # Beautiful premium color palette
    clean_colors = {
        'Positive': '#2ca02c',   # Deep Emerald Green
        'Neutral': '#ffbb78',    # Pastel Amber Yellow
        'Negative': '#d62728'    # Soft Crimson Red
    }

    # Creating a fully interactive and clean Pie Chart
    fig = px.pie(
        sentiment_counts,
        names="Sentiment Class",
        values="Total Reviews",
        hole=0.5,
        color="Sentiment Class",
        color_discrete_map=clean_colors
    )
    
    # Clean layout styling for the chart
    fig.update_layout(
        margin=dict(t=20, b=20, l=20, r=20),
        legend=dict(orientation="h", yanchor="bottom", y=-0.1, xanchor="center", x=0.5)
    )
    
    # Display the final polished chart
    st.plotly_chart(fig, use_container_width=True)

else:
    st.error("⚠️ System Alert: Could not locate the dataset file. Please check your storage directory.")

# --- SECTION 6: FOOTER WITH CLOSING REMARKS ---
st.divider()
st.caption("Mobile Sentiment Analysis Dashboard | Developed by Yasser ")
# Out:
# 2026-06-10 01:38:05.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 01:38:05.331 No runtime found, using MemoryCacheStorageManager
# 2026-06-10 01:38:05.335 No runtime found, using MemoryCacheStorageManager
# 2026-06-10 01:38:05.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 01:38:05.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 01:38:05.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 01:38:05.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 01:38:05.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
! streamlit run Overview.py
# Out:
# ^C

# %%
import pipreqs 
! pipreqs .
# Out:
# INFO: Not scanning for jupyter notebooks.
# WARNING: Import named "pandas" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "pandas" was resolved to "pandas:3.0.3" package (https://pypi.org/project/pandas/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# INFO: Successfully saved requirements file in .\requirements.txt
